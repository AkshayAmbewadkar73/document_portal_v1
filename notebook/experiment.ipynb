# %%
import logging
import os
from datetime import datetime

# %%
os.getcwd()
# Out:
# 'c:\\document_portal_v1\\notebook'

# %%
log_dir=os.path.join(os.getcwd(),"logs")
os.makedirs(log_dir,exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
LOG_FILE
# Out:
# '03_14_2026_22_01_15.log'

# %%
LOG_FILE_PATH=os.path.join(log_dir,LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger=logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyDM2KzvPwwiaas3RgS-6uZK-oxtO6MsevY"

emb = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

print(emb.embed_query("Hello world"))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\document_portal_v1\venv\lib\site-packages\langchain_google_genai\embeddings.py:480, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     479 try:
# --> 480     result = self.client.models.embed_content(
#     481         model=self.model,
#     482         contents=text,
#     483         config=config,
#     484     )
#     485 except ClientError as e:
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\models.py:5725, in Models.embed_content(self, model, contents, config)
#    5724 if not self._api_client.vertexai:
# -> 5725   return self._embed_content(model=model, contents=contents, config=config)
#    5727 if t.t_is_vertex_embed_content_model(model):
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\models.py:4725, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    4723 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4725 response = self._api_client.request(
#    4726     'post', path, request_dict, http_options
#    4727 )
#    4729 response_dict = {} if not response.body else json.loads(response.body)
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\_api_client.py:1402, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1399 http_request = self._build_request(
#    1400     http_method, path, request_dict, http_options
#    1401 )
# -> 1402 response = self._request(http_request, http_options, stream=False)
#    1403 response_body = (
#    1404     response.response_stream[0] if response.response_stream else ''
#    1405 )
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\_api_client.py:1238, in BaseApiClient._request(self, http_request, http_options, stream)
#    1236     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1238 return self._retry(self._request_once, http_request, stream)
#
# File c:\document_portal_v1\venv\lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\document_portal_v1\venv\lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\document_portal_v1\venv\lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\document_portal_v1\venv\lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File c:\document_portal_v1\venv\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File c:\document_portal_v1\venv\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File c:\document_portal_v1\venv\lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\_api_client.py:1215, in BaseApiClient._request_once(self, http_request, stream)
#    1208 response = self._httpx_client.request(
#    1209     method=http_request.method,
#    1210     url=http_request.url,
#    (...)
#    1213     timeout=http_request.timeout,
#    1214 )
# -> 1215 errors.APIError.raise_for_response(response)
#    1216 return HttpResponse(
#    1217     response.headers, response if stream else [response.text]
#    1218 )
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File c:\document_portal_v1\venv\lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/embedding-001 is not found for API version v1beta, or is not supported for embedContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[2], line 8
#       4 os.environ["GOOGLE_API_KEY"] = "AIzaSyDM2KzvPwwiaas3RgS-6uZK-oxtO6MsevY"
#       6 emb = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
# ----> 8 print(emb.embed_query("Hello world"))
#
# File c:\document_portal_v1\venv\lib\site-packages\langchain_google_genai\embeddings.py:487, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     485 except ClientError as e:
#     486     msg = f"Error embedding content ({e.status}): {e}"
# --> 487     raise GoogleGenerativeAIError(msg) from e
#     488 except Exception as e:
#     489     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/embedding-001 is not found for API version v1beta, or is not supported for embedContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
